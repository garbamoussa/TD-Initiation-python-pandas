# %% [markdown]
# # TP Statistiques Descriptives
# ## Analyse Univariée et Forme de Distribution
#
# ---
#
# ## **OBJECTIFS DU TP**
#
# À la fin de ce TP, vous serez capable de :
# -  Identifier et classer les différents types de variables
# -  Calculer et interpréter les indicateurs de tendance centrale et de dispersion
# -  Créer des visualisations appropriées selon le type de variable
# -  Analyser la forme d'une distribution (asymétrie, aplatissement)
# -  Détecter et traiter les valeurs aberrantes
# -  Tester la normalité d'une distribution
# -  Produire un rapport d'analyse statistique complet
#
# ---
#
# ## **PARTIE 1 : INSTALLATION ET DÉCOUVERTE **
#
# ### **Section 1.1 : Préparation de l'environnement**
#
# #### Question 1.1.1
# **Installez les bibliothèques Python nécessaires. Quelles sont les 5 bibliothèques principales dont vous aurez besoin pour l'analyse statistique et la visualisation ?**
#
# 💡 *Indice : Pensez aux bibliothèques pour manipuler les données, faire des calculs numériques, créer des graphiques et effectuer des tests statistiques.*
#
#
# ---
#
# #### Question 1.1.2
# **Créez un premier dataset simple avec 100 observations contenant les colonnes suivantes :**
# - `age` (entier entre 18 et 65)
# - `salaire` (distribution normale, moyenne 35000, écart-type 8000)
# - `categorie` (valeurs aléatoires : 'A', 'B', 'C')
# - `satisfaction` (entier entre 1 et 5)
#
# **Affichez les 10 premières lignes et les informations générales du dataset.**
#
# 💡 *Indice : Utilisez `np.random.seed()` pour avoir des résultats reproductibles.*
#
# ---
#
# #### Question 1.1.3
# **En observant votre dataset :**
# - Combien de lignes et de colonnes avez-vous ?
# - Quels sont les types de données (dtype) de chaque colonne ?
# - Y a-t-il des valeurs manquantes ?
#
# ---
#
# ## **PARTIE 2 : TYPES DE VARIABLES **
#
# ### **Section 2.1 : Identification des types**
#
# #### Question 2.1.1
# **Pour chaque variable de votre dataset initial, identifiez son type statistique :**
# - `age` : ?
# - `salaire` : ?
# - `categorie` : ?
# - `satisfaction` : ?
#
# **Justifiez chaque réponse en expliquant pourquoi vous avez choisi ce type.**
#
# *Indice : Posez-vous les questions : La variable est-elle numérique ? Y a-t-il un ordre ? Peut-elle prendre n'importe quelle valeur ?*
#
# ---
#
# #### Question 2.1.2
# **Créez un nouveau dataset plus complet avec 200 observations contenant :**
#
# | Variable | Description | Type attendu |
# |----------|-------------|--------------|
# | `ville` | Paris, Lyon, Marseille, Toulouse | ? |
# | `sexe` | H, F | ? |
# | `niveau_etude` | Bac, Licence, Master, Doctorat | ? |
# | `satisfaction` | 1 à 5 | ? |
# | `nb_enfants` | 0, 1, 2, 3... | ? |
# | `age` | 22 à 65 ans | ? |
# | `salaire` | En euros | ? |
# | `taille` | En cm | ? |
# | `experience` | Années d'expérience | ? |
#
# **Pour chaque variable, indiquez son type statistique et justifiez.**
#
# ---
#
# #### Question 2.1.3
# **Quelle est la différence entre :**
# - Une variable discrète et une variable continue ?
# - Une variable ordinale et une variable nominale ?
# - Une variable ordinale et une variable discrète ?
#
# **Donnez un exemple pour chaque cas.**
#
# ---
#
# ### **Section 2.2 : Codage des variables**
#
# #### Question 2.2.1
# **Comment devez-vous coder informatiquement les variables suivantes ?**
# - Variables nominales (`ville`, `sexe`) → Type Python : ?
# - Variables ordinales (`niveau_etude`) → Type Python : ? (avec ordre ?)
# - Variables continues (`salaire`, `taille`) → Type Python : ?
#
# **Écrivez le code pour convertir correctement vos variables.**
#
# ---
#
# #### Question 2.2.2
# **Pour la variable `niveau_etude`, créez un ordre logique :**
# Bac < Licence < Master < Doctorat
#
# **Vérifiez que l'ordre est bien pris en compte. Comment pouvez-vous le vérifier ?**
#
# ---
#
# #### Question 2.2.3
# **Pourquoi est-il important de coder correctement les variables ordinales avec leur ordre ?**
# **Que se passerait-il si vous traitez une variable ordinale comme nominale ?**
#
# ---
#
# ## **PARTIE 3 : TENDANCE CENTRALE **
#
# ### **Section 3.1 : Calcul des indicateurs**
#
# #### Question 3.1.1
# **Pour la variable `salaire` de votre dataset, calculez :**
# - La moyenne
# - La médiane
# - Le 1er quartile (Q1)
# - Le 3ème quartile (Q3)
#
# **Affichez les résultats avec 2 décimales.**
#
# ---
#
# #### Question 3.1.2
# **Quelle est la différence entre la moyenne et la médiane de votre variable `salaire` ?**
# **Que vous indique cette différence sur la distribution ?**
#
# 💡 *Indice : Si Moyenne > Médiane, qu'est-ce que cela signifie ?*
#
# ---
#
# #### Question 3.1.3
# **Pour la variable `satisfaction` (1 à 5), calculez :**
# - Le mode (valeur la plus fréquente)
# - La médiane
# - La moyenne
#
# **Laquelle de ces trois mesures est la plus appropriée pour une échelle de Likert ? Pourquoi ?**
#
# ---
#
# ### **Section 3.2 : Impact des valeurs extrêmes**
#
# #### Question 3.2.1
# **Créez une liste de salaires :**
# ```
# salaires_normaux = [25000, 28000, 30000, 32000, 35000, 38000, 40000, 42000]
# ```
#
# **Calculez la moyenne et la médiane.**
#
# ---
#
# #### Question 3.2.2
# **Ajoutez maintenant le salaire d'un PDG (500000€) à la liste :**
# ```
# salaires_avec_pdg = salaires_normaux + [500000]
# ```
#
# **Recalculez la moyenne et la médiane.**
#
# **Questions :**
# - De combien a augmenté la moyenne ?
# - De combien a augmenté la médiane ?
# - Quelle mesure est la plus "stable" face aux valeurs extrêmes ?
# - Laquelle représente mieux le salaire "typique" ?
#
# ---
#
# #### Question 3.2.3
# **Créez une fonction `analyser_tendance_centrale(data, nom_variable)` qui :**
# 1. Calcule moyenne, médiane, Q1, Q3
# 2. Affiche tous ces indicateurs
# 3. Compare moyenne et médiane
# 4. Donne une interprétation automatique (distribution symétrique ou asymétrique)
#
# **Testez votre fonction sur les variables `salaire` et `age`.**
#
# ---
#
# ### **Section 3.3 : Choix de l'indicateur**
#
# #### Question 3.3.1
# **Pour chacune des situations suivantes, quel indicateur de tendance centrale recommandez-vous ? Justifiez.**
#
# | Situation | Indicateur recommandé | Justification |
# |-----------|----------------------|---------------|
# | Prix des maisons dans une ville | ? | ? |
# | Notes d'un examen facile (distribution : 15, 16, 18, 19, 20, 20, 20) | ? | ? |
# | Taille des adultes français | ? | ? |
# | Revenus des ménages français | ? | ? |
# | Niveau de satisfaction client (1-5) | ? | ? |
#
# ---
#
# ## **PARTIE 4 : MESURES DE DISPERSION **
#
# ### **Section 4.1 : Calcul des mesures**
#
# #### Question 4.1.1
# **Pour la variable `salaire`, calculez :**
# - L'étendue (max - min)
# - La variance
# - L'écart-type
# - L'écart interquartile (IQR)
# - Le coefficient de variation (CV)
#
# **Affichez chaque résultat avec son interprétation.**
#
# ---
#
# #### Question 4.1.2
# **Pour les données suivantes, calculez manuellement (étape par étape) la variance et l'écart-type :**
# ```
# donnees = [10, 15, 20, 25, 30]
# ```
#
# **Étapes à suivre :**
# 1. Calculer la moyenne
# 2. Calculer les écarts à la moyenne (xi - moyenne)
# 3. Élever au carré chaque écart
# 4. Calculer la moyenne des carrés (variance)
# 5. Prendre la racine carrée (écart-type)
#
# **Vérifiez votre résultat avec les fonctions Python.**
#
# ---
#
# #### Question 4.1.3
# **Quelle est la différence entre :**
# - Variance et écart-type ? Pourquoi utilise-t-on plus souvent l'écart-type ?
# - Écart-type et IQR ? Quand préférer l'un ou l'autre ?
# - Étendue et IQR ? Laquelle est plus robuste ?
#
# ---
#
# ### **Section 4.2 : Coefficient de variation**
#
# #### Question 4.2.1
# **Vous avez deux groupes :**
# - **Groupe A** : Poids adultes (moyenne = 70 kg, écart-type = 10 kg)
# - **Groupe B** : Poids bébés (moyenne = 3.5 kg, écart-type = 0.5 kg)
#
# **Questions :**
# - Calculez le CV pour chaque groupe
# - Quel groupe est le plus homogène en termes de variabilité relative ?
# - Pourquoi ne peut-on pas comparer directement les écarts-types ?
#
# ---
#
# #### Question 4.2.2
# **Interprétez les coefficients de variation suivants :**
# - CV = 8% → ?
# - CV = 25% → ?
# - CV = 45% → ?
#
# **Pour chaque cas, dites si les données sont homogènes, modérément dispersées ou hétérogènes.**
#
# ---
#
# ### **Section 4.3 : Comparaison de dispersions**
#
# #### Question 4.3.1
# **Créez deux groupes de données :**
# - Groupe A : Distribution normale (moyenne=50, écart-type=5, n=100)
# - Groupe B : Distribution normale (moyenne=50, écart-type=15, n=100)
#
# **Pour chaque groupe, calculez et comparez :**
# - L'écart-type
# - L'IQR
# - Le coefficient de variation
#
# **Visualisez les deux distributions avec des histogrammes côte à côte.**
#
# **Question : Comment la dispersion affecte-t-elle visuellement la distribution ?**
#
# ---
#
# #### Question 4.3.2
# **Créez une fonction `analyser_dispersion(data, nom_variable)` qui :**
# 1. Calcule toutes les mesures de dispersion
# 2. Calcule le coefficient de variation
# 3. Interprète automatiquement le CV (< 15% : faible, 15-30% : modéré, > 30% : fort)
# 4. Affiche un résumé formaté
#
# **Testez sur vos variables `salaire` et `age`.**
#
# ---
#
# ## **PARTIE 5 : VISUALISATIONS **
#
# ### **Section 5.1 : Histogrammes**
#
# #### Question 5.1.1
# **Créez un histogramme pour la variable `salaire` avec :**
# - 30 classes (bins)
# - Couleur bleue claire, bordures noires
# - Lignes verticales pour la moyenne (rouge) et la médiane (verte)
# - Titre et labels des axes
# - Légende
#
# **À quoi ressemble la distribution ? Symétrique ou asymétrique ?**
#
# ---
#
# #### Question 5.1.2
# **Testez différents nombres de bins (5, 15, 30, 50) pour la même variable.**
#
# **Questions :**
# - Quel nombre de bins donne la meilleure visualisation ?
# - Que se passe-t-il avec trop peu de bins ?
# - Que se passe-t-il avec trop de bins ?
# - Quelle règle pouvez-vous appliquer pour choisir le nombre optimal ?
#
# 💡 *Indice : Règle de Sturges ou √n*
#
# ---
#
# #### Question 5.1.3
# **Créez une fonction `creer_histogramme_complet(data, nom_variable, bins=30)` qui :**
# 1. Crée l'histogramme
# 2. Ajoute la moyenne et la médiane en lignes verticales
# 3. Superpose une courbe normale théorique
# 4. Affiche les statistiques dans un encadré (n, moyenne, écart-type, médiane)
# 5. Ajoute titre et labels appropriés
#
# **Testez sur `salaire` et `age`.**
#
# ---
#
# ### **Section 5.2 : Boîtes à moustaches**
#
# #### Question 5.2.1
# **Créez un boxplot pour la variable `salaire`.**
#
# **Questions d'interprétation :**
# - Où se situe Q1 ? Q2 (médiane) ? Q3 ?
# - Les moustaches vont jusqu'où ?
# - Y a-t-il des points isolés (outliers) ?
# - La distribution est-elle symétrique (médiane centrée dans la boîte) ?
#
# ---
#
# #### Question 5.2.2
# **Sur votre boxplot, identifiez visuellement :**
# - La médiane (ligne centrale)
# - L'IQR (hauteur de la boîte)
# - Les limites de détection des outliers (extrémités des moustaches)
# - Les valeurs aberrantes éventuelles (points isolés)
#
# **Calculez ces valeurs numériquement et vérifiez qu'elles correspondent au graphique.**
#
# ---
#
# #### Question 5.2.3
# **Créez une figure avec deux boxplots côte à côte :**
# - Un vertical
# - Un horizontal
#
# **Pour le horizontal, ajoutez les points individuels superposés avec transparence.**
#
# **Question : Quel format préférez-vous pour la présentation ? Pourquoi ?**
#
# ---
#
# ### **Section 5.3 : Graphiques pour variables catégorielles**
#
# #### Question 5.3.1
# **Pour la variable `ville`, créez :**
# 1. Un diagramme en barres vertical
# 2. Un diagramme circulaire (camembert)
#
# **Affichez les effectifs sur les barres et les pourcentages sur le camembert.**
#
# ---
#
# #### Question 5.3.2
# **Créez un tableau de fréquences pour la variable `niveau_etude` montrant :**
# - Modalité
# - Effectif
# - Pourcentage
# - Pourcentage cumulé
#
# **Quel niveau d'études est le plus représenté ?**
#
# ---
#
# #### Question 5.3.3
# **Pour la variable `niveau_etude` (ordinale), créez un diagramme en barres :**
# - Barres ordonnées selon l'ordre logique (Bac → Doctorat)
# - Couleurs dégradées selon le niveau
# - Effectifs affichés sur chaque barre
#
# **Pourquoi est-il important de respecter l'ordre pour une variable ordinale ?**
#
# ---
#
# ### **Section 5.4 : Choix du graphique approprié**
#
# #### Question 5.4.1
# **Complétez le tableau suivant en indiquant le(s) graphique(s) le(s) plus approprié(s) :**
#
# | Type de variable | Variable exemple | Graphique(s) recommandé(s) |
# |------------------|------------------|----------------------------|
# | Nominale | Couleur préférée | ? |
# | Ordinale | Niveau de satisfaction | ? |
# | Discrète | Nombre d'enfants | ? |
# | Continue | Salaire | ? |
#
# ---
#
# #### Question 5.4.2
# **Pour chaque situation, choisissez le graphique le plus approprié et justifiez :**
#
# 1. Comparer les salaires de 3 départements différents → ?
# 2. Montrer la distribution des âges dans une population → ?
# 3. Identifier les parts de marché de 4 entreprises → ?
# 4. Détecter les valeurs aberrantes dans des données de température → ?
# 5. Visualiser la répartition des diplômes dans une entreprise → ?
#
# ---
#
# ## **PARTIE 6 : FORME DE DISTRIBUTION **
#
# ### **Section 6.1 : Asymétrie (Skewness)**
#
# #### Question 6.1.1
# **Calculez le skewness pour les variables suivantes de votre dataset :**
# - `salaire`
# - `age`
# - `taille`
#
# **Pour chaque variable, indiquez si la distribution est :**
# - Symétrique (skewness ≈ 0)
# - Asymétrique à droite (skewness > 0)
# - Asymétrique à gauche (skewness < 0)
#
# ---
#
# #### Question 6.1.2
# **Créez trois distributions artificielles pour illustrer les différents types d'asymétrie :**
#
# 1. **Distribution symétrique** : normale (moyenne=50, écart-type=10, n=1000)
# 2. **Asymétrique à droite** : mélange de normales (majoritairement basses, quelques très hautes)
# 3. **Asymétrique à gauche** : 100 - |normale|
#
# **Pour chacune :**
# - Calculez skewness, moyenne et médiane
# - Créez un histogramme
# - Vérifiez la relation entre moyenne et médiane selon l'asymétrie
#
# ---
#
# #### Question 6.1.3
# **Créez une fonction `analyser_asymetrie(data, nom_variable)` qui :**
# 1. Calcule skewness, moyenne et médiane
# 2. Détermine le type d'asymétrie
# 3. Crée une visualisation (histogramme + boxplot)
# 4. Fournit une interprétation automatique
# 5. Donne des exemples de phénomènes réels avec cette asymétrie
#
# **Testez sur vos données.**
#
# ---
#
# ### **Section 6.2 : Aplatissement (Kurtosis)**
#
# #### Question 6.2.1
# **Calculez le kurtosis (excès) pour vos variables continues.**
#
# **Pour chaque valeur obtenue, indiquez si la distribution est :**
# - Mésokurtique (kurtosis ≈ 0) : normale
# - Leptokurtique (kurtosis > 0) : pic pointu, queues épaisses
# - Platykurtique (kurtosis < 0) : pic aplati, queues fines
#
# ---
#
# #### Question 6.2.2
# **Créez trois distributions pour illustrer les différents types de kurtosis :**
#
# 1. **Mésokurtique** : normale standard
# 2. **Leptokurtique** : mélange de deux normales (une très concentrée + outliers)
# 3. **Platykurtique** : distribution uniforme
#
# **Pour chacune, calculez le kurtosis et créez un histogramme comparatif.**
#
# ---
#
# #### Question 6.2.3
# **Questions de réflexion :**
# - Quelle est la différence entre skewness et kurtosis ?
# - Peut-on avoir une distribution avec skewness = 0 et kurtosis ≠ 0 ?
# - Quelle mesure (skewness ou kurtosis) est généralement plus importante pour l'analyse ? Pourquoi ?
#
# ---
#
# ### **Section 6.3 : Détection des outliers**
#
# #### Question 6.3.1
# **Méthode IQR - Pour la variable `salaire` :**
#
# 1. Calculez Q1 et Q3
# 2. Calculez l'IQR
# 3. Calculez les limites inférieure et supérieure (Q1 - 1.5×IQR et Q3 + 1.5×IQR)
# 4. Identifiez les outliers (valeurs en dehors des limites)
# 5. Combien d'outliers avez-vous détecté ?
# 6. Affichez leurs valeurs
#
# ---
#
# #### Question 6.3.2
# **Méthode Z-score - Pour la même variable :**
#
# 1. Calculez la moyenne et l'écart-type
# 2. Calculez le Z-score pour chaque observation
# 3. Identifiez les outliers (|Z| > 3)
# 4. Combien d'outliers avez-vous détecté ?
# 5. Comparez avec la méthode IQR : trouvez-vous les mêmes outliers ?
#
# ---
#
# #### Question 6.3.3
# **Créez deux fonctions :**
#
# 1. `detecter_outliers_iqr(data, nom_variable)` qui :
#    - Détecte les outliers par IQR
#    - Affiche statistiques et résultats
#    - Crée une visualisation (boxplot + scatter plot)
#
# 2. `detecter_outliers_zscore(data, nom_variable, seuil=3)` qui :
#    - Détecte les outliers par Z-score
#    - Affiche statistiques et résultats
#    - Crée une visualisation
#
# **Testez les deux méthodes sur vos données et comparez les résultats.**
#
# ---
#
# #### Question 6.3.4
# **Créez intentionnellement un dataset avec outliers :**
# ```
# donnees_normales = distribution normale (moyenne=100, écart-type=15, n=95)
# outliers = [50, 55, 160, 165, 170]
# donnees_completes = combiner les deux
# ```
#
# **Questions :**
# - Les deux méthodes détectent-elles les mêmes outliers ?
# - Laquelle est la plus stricte ?
# - Laquelle recommandez-vous et pourquoi ?
#
# ---
#
# #### Question 6.3.5
# **Réflexion sur le traitement des outliers :**
#
# **Pour chaque outlier détecté dans vos données, répondez :**
# 1. S'agit-il d'une erreur de mesure/saisie ?
# 2. Est-ce une observation valide mais extrême ?
# 3. Appartient-il à la population étudiée ?
#
# **Que décidez-vous de faire ? (conserver, transformer, supprimer)**
# **Justifiez votre décision.**
#
# ---
#
# ## **PARTIE 7 : TESTS DE NORMALITÉ **
#
# ### **Section 7.1 : Tests visuels**
#
# #### Question 7.1.1
# **Pour la variable `salaire`, créez les trois visualisations suivantes :**
#
# 1. **Histogramme avec courbe normale théorique superposée**
#    - La distribution ressemble-t-elle à une cloche ?
#    - Les données suivent-elles bien la courbe ?
#
# 2. **QQ-plot**
#    - Les points sont-ils alignés sur la diagonale ?
#    - Y a-t-il des écarts aux extrémités ?
#
# 3. **Boxplot**
#    - La médiane est-elle centrée dans la boîte ?
#    - Les moustaches sont-elles équilibrées ?
#
# **Conclusion visuelle : Les données semblent-elles normales ?**
#
# ---
#
# #### Question 7.1.2
# **Créez une fonction `tests_visuels_normalite(data, nom_variable)` qui crée une figure avec 5 graphiques :**
# 1. Histogramme + courbe normale
# 2. QQ-plot
# 3. Boxplot
# 4. Distribution cumulée vs normale théorique
# 5. Résidus normalisés
#
# **La fonction doit aussi :**
# - Calculer skewness et kurtosis
# - Vérifier les critères de normalité (|skew| < 0.5, |kurt| < 1, moyenne ≈ médiane)
# - Donner une conclusion visuelle
#
# **Testez sur différentes variables.**
#
# ---
#
# ### **Section 7.2 : Tests statistiques**
#
# #### Question 7.2.1
# **Test de Shapiro-Wilk - Pour la variable `salaire` :**
#
# 1. Effectuez le test de Shapiro-Wilk
# 2. Notez la statistique W et la p-value
# 3. Avec un seuil α = 0.05, que concluez-vous ?
#    - Si p-value > 0.05 : Les données suivent une loi normale
#    - Si p-value ≤ 0.05 : Les données ne suivent pas une loi normale
#
# ---
#
# #### Question 7.2.2
# **Test d'Anderson-Darling - Pour la même variable :**
#
# 1. Effectuez le test d'Anderson-Darling
# 2. Notez la statistique A² et les valeurs critiques
# 3. Comparez A² à la valeur critique au seuil 5%
# 4. Conclusion : normale ou non-normale ?
#
# ---
#
# #### Question 7.2.3
# **Test de D'Agostino-Pearson (si n ≥ 20) :**
#
# 1. Effectuez le test
# 2. Notez la statistique K² et la p-value
# 3. Conclusion au seuil 5%
#
# ---
#
# #### Question 7.2.4
# **Créez une fonction `tests_statistiques_normalite(data, nom_variable, alpha=0.05)` qui :**
# 1. Effectue les 3 tests (si applicables)
# 2. Affiche les résultats de manière claire
# 3. Compare les conclusions
# 4. Donne une recommandation finale (normal ou non-normal)
#
# **Testez sur plusieurs variables.**
#
# ---
#
# ### **Section 7.3 : Synthèse normalité**
#
# #### Question 7.3.1
# **Testez la normalité complète (visuels + statistiques) pour :**
# - Une distribution normale artificielle
# - Une distribution exponentielle
# - Une distribution uniforme
#
# **Créez un tableau récapitulatif :**
#
# | Distribution | Skewness | Kurtosis | QQ-plot | Shapiro p-value | Anderson | Conclusion |
# |--------------|----------|----------|---------|-----------------|----------|------------|
# | Normale | ? | ? | ? | ? | ? | ? |
# | Exponentielle | ? | ? | ? | ? | ? | ? |
# | Uniforme | ? | ? | ? | ? | ? | ? |
#
# ---
#
# #### Question 7.3.2
# **Si vos données ne suivent pas une loi normale, quelles sont vos options ?**
#
# Listez et expliquez brièvement :
# 1. Transformation des données (log, racine, etc.)
# 2. Tests non-paramétriques
# 3. Méthodes robustes
# 4. Accepter la non-normalité (quand est-ce acceptable ?)
#
# ---
#
# ## **PARTIE 8 : PROJET FINAL - ANALYSE COMPLÈTE **
#
# ### **Mise en situation**
#
# Vous êtes data analyst dans une entreprise. On vous demande d'analyser les salaires annuels de 300 employés pour produire un rapport.
#
# #### Question 8.1 : Préparation des données
#
# **Créez un dataset réaliste de salaires avec :**
# - 200 salaires moyens (normale : 35000€, écart-type 5000€)
# - 70 salaires élevés (normale : 50000€, écart-type 8000€)
# - 25 salaires cadres (normale : 80000€, écart-type 15000€)
# - 5 salaires dirigeants (120000€, 150000€, 180000€, 200000€, 250000€)
#
# ---
#
# #### Question 8.2 : Analyse descriptive complète
#
# **Créez une fonction `analyse_complete_variable(data, nom_variable)` qui produit un rapport incluant :**
#
# **Section 1 : Informations générales**
# - Nombre d'observations
# - Valeurs min, max, étendue
# - Valeurs manquantes
#
# **Section 2 : Tendance centrale**
# - Moyenne, médiane, Q1, Q3
# - Interprétation de la symétrie
#
# **Section 3 : Dispersion**
# - Variance, écart-type, IQR, CV
# - Interprétation de l'homogénéité
#
# **Section 4 : Forme**
# - Skewness et kurtosis
# - Type de distribution
#
# **Section 5 : Outliers**
# - Détection IQR et Z-score
# - Liste des outliers
#
# **Section 6 : Normalité**
# - Tests visuels et statistiques
# - Conclusion sur la normalité
#
# **Section 7 : Visualisations**
# - 6 à 8 graphiques pertinents
#
# **Section 8 : Recommandations**
# - Tests statistiques à utiliser
# - Indicateur de tendance recommandé
# - Transformations suggérées
# - Traitement des outliers
#
# ---
#
# #### Question 8.3 : Application
#
# **Lancez votre fonction d'analyse complète sur le dataset de salaires.**
#
# **Questions d'interprétation :**
#
# 1. **Distribution** : Les salaires suivent-ils une loi normale ? Pourquoi ou pourquoi pas ?
#
# 2. **Tendance centrale** : Quel indicateur (moyenne ou médiane) représente le mieux le salaire "typique" ? Justifiez.
#
# 3. **Outliers** : Avez-vous détecté des outliers ? Que recommandez-vous de faire avec eux ?
#
# 4. **Tests statistiques** : Si vous deviez comparer ces salaires à un autre groupe, quel test utiliseriez-vous ?
#
# 5. **Communication** : Si vous deviez présenter ces résultats à la direction (non-statisticienne), quels sont les 3 chiffres clés et le graphique principal à montrer ?
#
# ---
#
# #### Question 8.4 : Exercice bonus
#
# **Chargez un dataset réel (Iris, Boston Housing, Titanic, etc.) et réalisez l'analyse complète de 3 variables continues.**
#
# **Comparez les trois variables :**
# - Laquelle est la plus dispersée ?
# - Laquelle est la plus asymétrique ?
# - Laquelle suit le mieux une loi normale ?
#
# ---
